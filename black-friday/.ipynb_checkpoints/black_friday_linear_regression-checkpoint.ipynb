# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import warnings
from sklearn.model_selection import cross_val_score

# %%
# %matplotlib inline
warnings.filterwarnings('ignore')
sns.set_style("darkgrid", {"axes.facecolor": ".9"})

# %% [markdown]
# Method to fit model and get predicted values

# %%
def model(X,Y):
    model = sm.OLS(Y,sm.add_constant(X))
    results = model.fit()
    print(results.summary())
    X_train,X_test,y_train,y_test = train_test_split(X,Y,random_state=10,test_size=0.3)
    lr = LinearRegression()
    lr.fit(X_train,y_train)
    scores = cross_val_score(lr, X_test,y_test, cv=2)
    print(" ****Score********* "+ str(lr.score(X_test,y_test)))
    print(" ****Intercept***** "+str(lr.intercept_))
    print(" ****Coefficient*** "+str(lr.coef_))
    print(" ****Cross Validation Score********* "+ str(scores))
    predictions =lr.predict(X_test)
    pred_df =pd.DataFrame({'y_test':y_test,'Predictions':predictions})
    return pred_df

# %%
def products(x,df):
    y=df[x].unique()
    for i in y :
        j='product_'+ str(i)
        if j in df.columns:
            df.loc[df[x] == i, j] = 1

# %%
def describe(df,col,out):
    fig = plt.figure(figsize=(8,8))
    df2=pd.DataFrame(df[col].value_counts())
    plt.pie(df2[col],autopct='%1.1f%%',labels=df2.index,startangle=90)
    plt.show()
    sns.boxplot(x=col,y=out,data=df)
    plt.show()

# %%
df = pd.read_csv('BlackFriday.csv')

# %%
df.shape
# Out:
# (537577, 12)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df['product_1']='0'
df['product_2']='0'
df['product_3']='0'
df['product_4']='0'
df['product_5']='0'
df['product_6']='0'
df['product_7']='0'
df['product_8']='0'
df['product_9']='0'
df['product_10']='0'
df['product_11']='0'
df['product_12']='0'
df['product_13']='0'
df['product_14']='0'
df['product_15']='0'
df['product_16']='0'
df['product_17']='0'
df['product_18']='0'
df['Product_Category_2'] = df['Product_Category_2'].fillna(0).astype(int)
df['Product_Category_3'] = df['Product_Category_3'].fillna(0).astype(int)
products('Product_Category_1',df)
products('Product_Category_2',df)
products('Product_Category_3',df)

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase', 'product_1',
#        'product_2', 'product_3', 'product_4', 'product_5', 'product_6',
#        'product_7', 'product_8', 'product_9', 'product_10', 'product_11',
#        'product_12', 'product_13', 'product_14', 'product_15', 'product_16',
#        'product_17', 'product_18'],
#       dtype='object')

# %%
describe(df,'Gender','Purchase')

# %%
fig = plt.figure(figsize=(5,5))
ax1 = fig.add_axes([0, 0, 1, 1])
df2=pd.DataFrame(df['Gender'].value_counts())
ax1 = plt.pie(df2['Gender'],autopct='%1.1f%%',labels=df2.index,startangle=90)
ax2 = fig.add_axes([1.25, .0, 1, 1])
sns.boxplot(x='Gender',y='Purchase',data=df,ax=ax2)
ax3 = fig.add_axes([0, -1.25, 1, 1])
df3=pd.DataFrame(df['Age'].value_counts())
ax3 = plt.pie(df3['Age'],autopct='%1.1f%%',labels=df3.index,startangle=90)
ax4 = fig.add_axes([1.25, -1.25, 1, 1])
sns.boxplot(x='Age',y='Purchase',data=df,ax=ax4)
plt.show()

# %%
describe(df,'Age','Purchase')

# %%
describe(df,'Occupation','Purchase')

# %%
describe(df,'City_Category','Purchase')

# %%
describe(df,'Stay_In_Current_City_Years','Purchase')

# %%
describe(df,'Marital_Status','Purchase')

# %%
sns.distplot(df['Purchase'])

# %%
df_0_17 = df[df['Age']=='0-17']
df_18_25 = df[df['Age']=='18-25']
df_26_35 = df[df['Age']=='26-35']
df_36_45 = df[df['Age']=='36-45']
df_46_50 = df[df['Age']=='46-50']
df_51_55 = df[df['Age']=='51-55']
df_55_plus = df[df['Age']=='55+']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-183-c65c12dc5fc5> in <module>()
# ----> 1 df_0_17 = df[df['Age']=='0-17'].astype(float)
#       2 df_18_25 = df[df['Age']=='18-25'].astype(float)
#       3 df_26_35 = df[df['Age']=='26-35'].astype(float)
#       4 df_36_45 = df[df['Age']=='36-45'].astype(float)
#       5 df_46_50 = df[df['Age']=='46-50'].astype(float)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
# ...

# %%
print(df_0_17.shape)
print(df_18_25.shape)
print(df_26_35.shape)
print(df_36_45.shape)
print(df_46_50.shape)
print(df_51_55.shape)
print(df_55_plus.shape)
# Out:
# (14707, 30)
# (97634, 30)
# (214690, 30)
# (107499, 30)
# (44526, 30)
# (37618, 30)
# (20903, 30)

# %%
sns.distplot(df_0_17['Purchase'])

# %%
sns.distplot(df_0_17[(df_0_17['Purchase']>15000) & (df_0_17['Purchase']<=18000)]['Purchase'])

# %%
df[(df['Purchase']>15000) & (df['Purchase']<=18000)]['Occupation'].value_counts()
# Out:
# 4     8361
# 0     8013
# 7     7752
# 17    5773
# 1     5002
# 12    4235
# 14    3555
# 20    3362
# 16    3333
# 2     2711
# 6     2316
# 3     1959
# 15    1624
# 5     1456
# 10    1384
# 11    1319
# 13     855
# 19     842
# 18     823
# 9      572
# 8      227
# Name: Occupation, dtype: int64

# %%
df_0_17.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase', 'product_1',
#        'product_2', 'product_3', 'product_4', 'product_5', 'product_6',
#        'product_7', 'product_8', 'product_9', 'product_10', 'product_11',
#        'product_12', 'product_13', 'product_14', 'product_15', 'product_16',
#        'product_17', 'product_18'],
#       dtype='object')

# %%
df_0_17.groupby(by='Age',as_index=True)
# Out:
#       User_ID  Product_ID  Gender  Occupation  City_Category  \
# Age
# 0-17    14707       14707   14707       14707          14707
#
#       Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# Age
# 0-17                       14707           14707               14707
#
#       Product_Category_2  Product_Category_3     ...      product_9  \
# Age                                              ...
# 0-17               14707               14707     ...          14707
#
#       product_10  product_11  product_12  product_13  product_14  product_15  \
# Age
# 0-17       14707       14707       14707       14707       14707       14707
#
#       product_16  product_17  product_18
# Age
# 0-17       14707       14707       14707
#
# [1 rows x 29 columns]

# %%
retail_df = pd.get_dummies(data=df,columns=['Age','Occupation','City_Category'],drop_first=True)
retail_df['Total_Purchase']=retail_df['Purchase']
retail_df.drop(labels=['Purchase','User_ID','Product_ID','Product_Category_1','Product_Category_2',
                        'Product_Category_3','Stay_In_Current_City_Years','Marital_Status'],axis=1,inplace=True)
retail_df['Gender'] = retail_df['Gender'].map({'F':0,'M':1})
retail_df=retail_df.astype(float)

# %%
retail_df.shape
# Out:
# (537577, 48)

# %%
def model_params(X,Y) :
    col = X.name
    X = sm.add_constant(X)
    model = sm.OLS(Y,X)
    results = model.fit()
    rsq = round(results.rsquared,4)
    rsquared[col]=rsq
    adj_rsq = round(results.rsquared_adj,4)
    adj_rsquared[col]=adj_rsq
    pvalue = round(results.pvalues,4)
    pvalues[col]=pvalue[1]
cols= retail_df.iloc[:,:-1].columns.values
y = retail_df.iloc[:,-1]
pvalues = {}
rsquared = {}
adj_rsquared = {}
for i in range(0,len(cols)) :
    model_params(retail_df[cols[i]],y)
df_params = pd.DataFrame(np.row_stack([pd.DataFrame(rsquared,index=[0]),pd.DataFrame(adj_rsquared,index=[0]),pd.DataFrame(pvalues,index=[0])]),columns=cols,index=['r_sq','adj_rsq','pvalue'])

# %%
df_params.T
# Out:
#                    r_sq  adj_rsq  pvalue
# Gender           0.0036   0.0036  0.0000
# product_1        0.2551   0.2551  0.0000
# product_2        0.0770   0.0770  0.0000
# product_3        0.0018   0.0018  0.0000
# product_4        0.0070   0.0070  0.0000
# product_5        0.1085   0.1085  0.0000
# product_6        0.0674   0.0674  0.0000
# product_7        0.0104   0.0104  0.0000
# product_8        0.0062   0.0062  0.0000
# product_9        0.0001   0.0001  0.0000
# product_10       0.0479   0.0479  0.0000
# product_11       0.0256   0.0256  0.0000
# product_12       0.0103   0.0103  0.0000
# product_13       0.0019   0.0019  0.0000
# product_14       0.0122   0.0122  0.0000
# product_15       0.0292   0.0292  0.0000
# product_16       0.0337   0.0337  0.0000
# product_17       0.0046   0.0046  0.0000
# product_18       0.0010   0.0010  0.0000
# Age_18-25        0.0001   0.0001  0.0000
# Age_26-35        0.0000   0.0000  0.0207
# Age_36-45        0.0000   0.0000  0.0000
# ...

# %%
X =retail_df.iloc[:,:-1]
Y = retail_df.iloc[:,-1]
pred=model(X,Y)
sns.lmplot(x='y_test', y='Predictions',data=pred)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Total_Purchase   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                 1.003e+04
# Date:                Sat, 01 Sep 2018   Prob (F-statistic):               0.00
# Time:                        14:11:44   Log-Likelihood:            -5.1701e+06
# No. Observations:              537577   AIC:                         1.034e+07
# Df Residuals:                  537529   BIC:                         1.034e+07
# Df Model:                          47
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            7626.4971     53.361    142.922      0.000    7521.911    7731.083
# ...

# %%
X =retail_df.iloc[:,:-1].drop(labels=['Occupation_18'],axis=1)
Y = retail_df.iloc[:,-1]
pred=model(X,Y)
sns.lmplot(x='y_test', y='Predictions',data=pred)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Total_Purchase   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                 1.025e+04
# Date:                Sat, 01 Sep 2018   Prob (F-statistic):               0.00
# Time:                        14:12:24   Log-Likelihood:            -5.1701e+06
# No. Observations:              537577   AIC:                         1.034e+07
# Df Residuals:                  537530   BIC:                         1.034e+07
# Df Model:                          46
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            7626.9214     53.316    143.052      0.000    7522.424    7731.418
# ...

# %%
X =retail_df.iloc[:,:-1].drop(labels=['Occupation_18','Age_36-45'],axis=1)
Y = retail_df.iloc[:,-1]
pred=model(X,Y)
sns.lmplot(x='y_test', y='Predictions',data=pred)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Total_Purchase   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                 1.048e+04
# Date:                Sat, 01 Sep 2018   Prob (F-statistic):               0.00
# Time:                        14:12:55   Log-Likelihood:            -5.1701e+06
# No. Observations:              537577   AIC:                         1.034e+07
# Df Residuals:                  537531   BIC:                         1.034e+07
# Df Model:                          45
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            7603.8900     25.902    293.563      0.000    7553.123    7654.657
# ...

# %%
X =retail_df.iloc[:,:-1].drop(labels=['Occupation_18','Age_36-45','product_9'],axis=1)
Y = retail_df.iloc[:,-1]
pred=model(X,Y)
sns.lmplot(x='y_test', y='Predictions',data=pred)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Total_Purchase   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                 1.072e+04
# Date:                Sat, 01 Sep 2018   Prob (F-statistic):               0.00
# Time:                        14:13:24   Log-Likelihood:            -5.1701e+06
# No. Observations:              537577   AIC:                         1.034e+07
# Df Residuals:                  537532   BIC:                         1.034e+07
# Df Model:                          44
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            7602.4858     25.755    295.190      0.000    7552.008    7652.964
# ...

# %%
X =retail_df.iloc[:,:-1].drop(labels=['Occupation_18','Age_36-45','product_9','Age_46-50'],axis=1)
Y = retail_df.iloc[:,-1]
pred=model(X,Y)
sns.lmplot(x='y_test', y='Predictions',data=pred)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Total_Purchase   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                 1.097e+04
# Date:                Sat, 01 Sep 2018   Prob (F-statistic):               0.00
# Time:                        14:13:54   Log-Likelihood:            -5.1701e+06
# No. Observations:              537577   AIC:                         1.034e+07
# Df Residuals:                  537533   BIC:                         1.034e+07
# Df Model:                          43
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            7599.6915     25.177    301.854      0.000    7550.346    7649.037
# ...

# %%
X =retail_df.iloc[:,:-1].drop(labels=['Occupation_18','Age_36-45','product_9','Age_46-50','Gender'],axis=1)
Y = retail_df.iloc[:,-1]
pred=model(X,Y)
sns.lmplot(x='y_test', y='Predictions',data=pred)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Total_Purchase   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                 1.123e+04
# Date:                Sat, 01 Sep 2018   Prob (F-statistic):               0.00
# Time:                        14:14:25   Log-Likelihood:            -5.1701e+06
# No. Observations:              537577   AIC:                         1.034e+07
# Df Residuals:                  537534   BIC:                         1.034e+07
# Df Model:                          42
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            7594.4826     23.462    323.694      0.000    7548.498    7640.467
# ...

# %%
X =retail_df.iloc[:,:-1].drop(labels=['Occupation_18','Age_36-45','product_9','Age_46-50','Gender','Occupation_13'],axis=1)
Y = retail_df.iloc[:,-1]
pred=model(X,Y)
sns.lmplot(x='y_test', y='Predictions',data=pred)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Total_Purchase   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                 1.150e+04
# Date:                Sat, 01 Sep 2018   Prob (F-statistic):               0.00
# Time:                        14:14:54   Log-Likelihood:            -5.1701e+06
# No. Observations:              537577   AIC:                         1.034e+07
# Df Residuals:                  537535   BIC:                         1.034e+07
# Df Model:                          41
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            7598.6331     23.209    327.400      0.000    7553.144    7644.122
# ...

# %%
X =retail_df.iloc[:,:-1].drop(labels=['Occupation_18','Age_36-45','product_9','Age_46-50','Gender','Occupation_13','Occupation_5','Occupation_9','Occupation_2'],axis=1)
Y = retail_df.iloc[:,-1]
pred=model(X,Y)
sns.lmplot(x='y_test', y='Predictions',data=pred,size=5)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Total_Purchase   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                 1.241e+04
# Date:                Sat, 01 Sep 2018   Prob (F-statistic):               0.00
# Time:                        16:03:45   Log-Likelihood:            -5.1701e+06
# No. Observations:              537577   AIC:                         1.034e+07
# Df Residuals:                  537538   BIC:                         1.034e+07
# Df Model:                          38
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            7620.5310     21.852    348.738      0.000    7577.702    7663.360
# ...

# %%
df2 = df[(df['Age']=='0-17') & (df['Occupation']==0)]

# %%
df2.head()
# Out:
#       User_ID Product_ID Gender   Age  Occupation City_Category  \
# 4375  1000719  P00313542      M  0-17           0             C
# 6530  1001056  P00087442      M  0-17           0             C
# 7670  1001187  P00156442      F  0-17           0             A
# 8424  1001296  P00216742      M  0-17           0             C
# 8425  1001296  P00052642      M  0-17           0             C
#
#      Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4375                         4+               0                   5
# 6530                          1               0                   5
# 7670                          2               0                   8
# 8424                         4+               0                   5
# 8425                         4+               0                   5
#
#       Product_Category_2     ...      product_9  product_10  product_11  \
# 4375                   8     ...            0.0         0.0         0.0
# ...

# %%
retail_df2 = pd.get_dummies(data=df2,columns=['Age','Occupation','City_Category'],drop_first=True)
retail_df2['Total_Purchase']=retail_df2['Purchase']
retail_df2.drop(labels=['Purchase','User_ID','Product_ID','Product_Category_1','Product_Category_2',
                        'Product_Category_3','Stay_In_Current_City_Years','Marital_Status'],axis=1,inplace=True)
retail_df2['Gender'] = retail_df2['Gender'].map({'F':0,'M':1})
retail_df2=retail_df2.astype(float)

# %%
retail_df2.shape
# Out:
# (2044, 22)

# %%
X =retail_df2.iloc[:,:-1].drop(labels=['product_9','City_Category_B','product_8','product_18','Gender'],axis=1)
Y = retail_df2.iloc[:,-1]
pred=model(X,Y)
sns.lmplot(x='y_test', y='Predictions',data=pred)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Total_Purchase   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                     113.0
# Date:                Tue, 04 Sep 2018   Prob (F-statistic):          2.84e-266
# Time:                        23:29:07   Log-Likelihood:                -19637.
# No. Observations:                2044   AIC:                         3.931e+04
# Df Residuals:                    2027   BIC:                         3.940e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            8246.0198    176.528     46.712      0.000    7899.824    8592.215
# ...

# %%
df2.Occupation.value_counts()
# Out:
# 0    2044
# Name: Occupation, dtype: int64
